# %% [markdown]
# # Quakers  SNA #

# %% [markdown]
# ## This project explores the 593 Quakers found amongst the entire community of 3095 ##
#
# 19% of the community are Quakers.

# %%
import csv
from operator import itemgetter
import networkx as nx
from networkx.algorithms import community #This part of networkx, for community detection, needs to be imported separately.
import nbconvert

# %% [markdown]
# <img src="quakers.png">

# %%
with open('vw_4_quaker_nodes_202108191716.csv', 'r') as nodecsv: # Open the Nodes csv file
    nodereader = csv.reader(nodecsv) # Read the csv
    nodes = [n for n in nodereader][1:]# Retrieve the data (using Python list comprhension and list slicing
                                       # to remove the header row
    node_names = [n[0] for n in nodes] # Get a list of only the node names

with open('vw_5_person1_person2.csv', 'r') as edgecsv: # Open the file
    edgereader = csv.reader(edgecsv) # Read the csv
    edge_list = list(edgereader) # Convert to list, so can iterate below in for loop
    
    # Create empty arrays to store edge data and edge attribute data
    edges = []
    edges_attributes = []
    
    # Fill the arrays with data from CSV
    for e in edge_list[1:]:
        edges.append(tuple(e[0:2])) # Get the first 2 columns (source, target) and add to array
        edges_attributes.append(tuple(e[2:3])) # Get the 3rd column (relationship_type_id) and add to array
    
edge_names = [e[0] for e in edges] # Get a list of only the edge names

# %%
print("Nodes length: ", len(node_names))
print("Edges length: ", len(edges))
print("Edges attributes length: ", len(edges_attributes)) # This should be the same length as edges
# Out:
# Nodes length:  644
# Edges length:  2099
# Edges attributes length:  2099

# %%
print("First 5 nodes:", node_names[0:5])
print("First 5 edges:", edges[0:5])
print("First 5 edges attributes:", edges_attributes[0:5])

# The output will appear below this code cell.
# Out:
# First 5 nodes: ['William Spicer Wood', 'William Spicer Wood', 'William Spicer Wood', 'William Wilson', 'William Wilson']
# First 5 edges: [('William Aldam', 'x Fox'), ('William Jun Aldam', 'x Fox'), ('Frederick Alexander', 'R D Alexander'), ('G W Alexander', 'R D Alexander'), ('Henry Alexander', 'R D Alexander')]
# First 5 edges attributes: [('1',), ('1',), ('1',), ('1',), ('1',)]

# %%
G = nx.Graph()
G.add_nodes_from(node_names)
G.add_edges_from(edges)
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 593
# Number of edges: 2099
# Average degree:   7.0793

# %%
# Nodes attributes
birth_year_dict = {}
death_year_dict = {}
religion_name_dict = {}
ceda_name_dict = {}
person_ceda_first_year_dict = {}
person_ceda_last_year_dict = {}

# Edges attributes
relationship_type_id_dict = {}

# %%
for node in nodes: # Loop through the list, one row at a time
    birth_year_dict [node[0]] = node[1]
    death_year_dict [node[0]] = node[2]
    religion_name_dict [node[0]] = node[3]
    ceda_name_dict [node[0]] = node[4]
    person_ceda_first_year_dict [node[0]] = node[5]
    person_ceda_last_year_dict [node[0]] = node[6]

# %%
for i, edge in enumerate(edges): # Loop through the list, one row at a time
    relationship_type_id_dict [(edge[0], edge[1])] = edges_attributes[i][0]

# %%
print(religion_id_dict)# list Source, target and first_year (all records). This shows the data that will be exported to Gephi.
print(len(religion_id_dict))# At the end of the file print a count of all first_year check 3946)
# Out:
# {'William Aldam': '1', 'S  Stafford Allen': '1', 'Edward Backhouse': '1', 'James (1) Backhouse': '1', 'James Bell': '1', 'Antonio Brady': '1', 'William Bull': '1', 'Charles Buxton': '1', 'Henry Christy': '1', 'William Clay': '1', 'x Collier': '1', 'Henry Crowley': '1', 'David Dale': '1', 'James T J Doyle': '1', 'Robert Nicholas Fowler': '1', 'William Fowler': '1', 'Charles Henry Fox': '1', 'George Stacey Gibson': '1', 'John Henry Gurney': '1', 'Thomas (1) Hodgkin': '1', 'William Holmes': '1', 'Jonathan Hutchinson': '1', 'Joseph Lister': '1', 'William Horton Lloyd': '1', 'J Robinson': '1', 'John Ross': '1', 'E T Wakefield': '1', 'James Wilson': '1', 'William Wilson': '1', 'William Spicer Wood': '1', 'Arthur Albright': '1', 'Rachel Albright': '1', 'William Albright': '1', 'William Jun Aldam': '1', 'Frederick Alexander': '1', 'Samuel Allen': '1', 'John Arch': '1', 'R Arthington': '1', 'R Jun Arthington': '1', 'C Ashby': '1', 'T Jun Ashby': '1', 'Thomas Ashby': '1', 'Thomas Jun Ashby': '1', 'Catherine Backhouse': '1', 'Jonathan Backhouse': '1', 'S Baker': '1', 'Robert Barclay': '1', 'Richard Barrington': '1', 'Edward Beck': '1', 'Eliza Bell': '1', 'Frederick J Bell': '1', 'S S Bell': '1', 'Samuel Bewley': '1', 'x Biffin': '1', 'J Binyon': '1', 'E L Birkbeck': '1', 'H Birkbeck': '1', 'W Blaine': '1', 'Elizabeth Bowley': '1', 'Henry Brady': '1', 'Charles L Braithwaite': '1', 'L Braithwaite': '1', 'Isaac Brown': '1', 'Joshua Brown': '1', 'Lydia Brown': '1', 'Sarah Burgess': '1', 'Thomas Burgess': '1', 'Thomas Fowell Buxton': '1', 'W Catchpool': '1', 'x Charleton': '1', 'Samuel Clark': '1', 'W Clemes': '1', 'C Clothier': '1', 'Joseph Cooper': '1', 'George Crosfield': '1', 'Joseph Crosland': '1', 'A Crowley': '1', 'A Dale': '1', 'Elizabeth S Dawes': '1', 'John Dodshon': '1', 'Daniel Doncaster': '1', 'Elizabeth Dyer': '1', 'R Dymond': '1', 'William Dyson': '1', 'A Ellis': '1', 'Thomas Evans': '1', 'Ann Everett': '1', 'Joseph Farden': '1', 'John Fell': '1', 'Mary Fell': '1', 'S H Fisher': '1', 'Caleb Fletcher': '1', 'Martha Fletcher': '1', 'John Ford': '1', 'George Fox': '1', 'Henry Fox': '1', 'Robert Were Fox': '1', 'Thomas Fox': '1', 'x Fox': '1', 'W Gayner': '1', 'Joseph Gibbens': '1', 'Ann Gibson': '1', 'Francis Gibson': '1', 'F  E Gibson': '1', 'W G Gibson': '1', 'T Gill': '1', 'J Gillett': '1', 'John Gillett': '1', 'J Gilpin': '1', 'James Gingell': '1', 'John Good': '1', 'Josiah Grace': '1', 'Thomas Graham': '1', 'John Green': '1', 'T Gregory': '1', 'G Grimshaw': '1', 'x Hadfield': '1', 'Isaac Hadwen': '1', 'Robert Harding': '1', 'Henry Harris': '1', 'Lydia Harris': '1', 'Thomas Harvey': '1', 'George Head': '1', 'Sarah Head': '1', 'H Headley': '1', 'W Hewitson': '1', 'Charles Hicks': '1', 'Elizabeth Hills': '1', 'James Hills': '1', 'John Hills': '1', 'Gurney Hoare': '1', 'Maria Hooper': '1', 'J Hopkins': '1', 'Rebecca Hopkins': '1', 'Mary Horsnail': '1', 'Elizabeth Howard (2)': '1', 'Elizabeth Howard': '1', 'Thomas Hughes': '1', 'Henry Hunt': '1', 'T Hunt': '1', 'J Hurnard': '1', 'John C Isaac': '1', 'John James': '1', 'Charles Janson': '1', 'Samuel Jesper': '1', 'Benjamin Jowett (2)': '1', 'John Jun Jowett': '1', 'Robert Jowett (2)': '1', 'John King': '1', 'Samuel King': '1', 'Thomas King': '1', 'Alfred Kitching': '1', 'C Knight': '1', 'John Lee': '1', 'x Leitch': '1', 'Thomas Letchmore': '1', 'Thomas x Jun Letchmore': '1', 'Thomas Letchworth': '1', 'Thomas Jun Letchworth': '1', 'Thomas x Jun Letchworth': '1', 'S Lloyd': '1', 'Edward Lucas': '1', 'Rebecca Lucas': '1', 'Thomas Marriage': '1', 'John Marsh': '1', 'R Marsh': '1', 'William Matthews': '1', 'William Mattravers': '1', 'D Miller': '1', 'John Morrison': '1', 'E Neave': '1', 'Mary Overend': '1', 'W J Palmer': '1', 'J Pears': '1', 'Edward Priestman (2)': '1', 'John Priestman': '1', 'James Ransome': '1', 'Robert Ransome': '1', 'William Rathbone': '1', 'J Jun Read': '1', 'Edward Richardson': '1', 'Henry Richardson': '1', 'W Richardson': '1', 'R M Rickman': '1', 'S Rickman': '1' ...
# 593

# %%
# Nodes

nx.set_node_attributes(G, birth_year_dict, 'birth_year')
nx.set_node_attributes(G, death_year_dict, 'death_year')
nx.set_node_attributes(G, religion_name_dict, 'religion')
nx.set_node_attributes(G, ceda_name_dict,'ceda')
nx.set_node_attributes(G, person_ceda_first_year_dict, 'first_year') 
nx.set_node_attributes(G, person_ceda_last_year_dict, 'last_year')                    

# Edges
nx.set_node_attributes(G, relationship_type_id_dict, 'relationship_weight')

# %%
for n in G.nodes(): # Loop through every node, in our data "n" will be the name of the person
    print(n, G.nodes[n]['birth_year']) # Access every node by its name, and then by the attribute "birth_year"
# Out:
# William Spicer Wood
# William Wilson 1785
# James Wilson
# E T Wakefield
# John Ross
# J Robinson
# William Horton Lloyd
# Joseph Lister 1827
# Jonathan Hutchinson 1828
# William Holmes
# Thomas (1) Hodgkin 1798
# John Henry Gurney 1819
# George Stacey Gibson 1818
# Charles Henry Fox
# William Fowler
# Robert Nicholas Fowler 1828
# James T J Doyle
# David Dale 1829
# Henry Crowley
# x Collier
# William Clay 1791
# Henry Christy 1810
# Charles Buxton 1823
# William Bull 1828
# Antonio Brady 1811
# James Bell 1818
# James (1) Backhouse 1794
# Edward Backhouse 1808
# S  Stafford Allen 1840
# William Aldam 1813
# Arthur Albright
# Rachel Albright
# William Albright
# William Jun Aldam
# Frederick Alexander
# Samuel Allen
# John Arch
# R Arthington
# R Jun Arthington
# C Ashby
# T Jun Ashby
# Thomas Ashby
# Thomas Jun Ashby
# Catherine Backhouse
# Jonathan Backhouse
# S Baker
# Robert Barclay
# Richard Barrington
# Edward Beck
# Eliza Bell
# Frederick J Bell
# S S Bell
# Samuel Bewley
# x Biffin
# J Binyon
# E L Birkbeck
# H Birkbeck
# W Blaine
# Elizabeth Bowley
# Henry Brady
# Charles L Braithwaite
# L Braithwaite
# Isaac Brown
# Joshua Brown
# Lydia Brown
# Sarah Burgess
# Thomas Burgess
# Thomas Fowell Buxton
# W Catchpool
# x Charleton
# Samuel Clark
# W Clemes
# C Clothier
# Joseph Cooper
# George Crosfield
# Joseph Crosland
# A Crowley
# A Dale
# Elizabeth S Dawes
# John Dodshon
# Daniel Doncaster
# Elizabeth Dyer
# R Dymond
# William Dyson
# A Ellis
# Thomas Evans
# Ann Everett
# Joseph Farden
# John Fell
# Mary Fell
# S H Fisher
# Caleb Fletcher
# Martha Fletcher
# John Ford
# George Fox
# Henry Fox
# Robert Were Fox
# Thomas Fox
# x Fox
# W Gayner
# Joseph Gibbens
# Ann Gibson
# Francis Gibson
# F  E Gibson
# W G Gibson
# T Gill
# J Gillett
# John Gillett
# J Gilpin
# James Gingell
# John Good
# Josiah Grace
# Thomas Graham
# John Green
# T Gregory
# G Grimshaw
# x Hadfield
# Isaac Hadwen
# Robert Harding
# Henry Harris
# Lydia Harris
# Thomas Harvey
# George Head
# Sarah Head
# H Headley
# W Hewitson
# Charles Hicks
# Elizabeth Hills
# James Hills
# John Hills
# Gurney Hoare
# Maria Hooper
# J Hopkins
# Rebecca Hopkins
# Mary Horsnail
# Elizabeth Howard (2)
# Elizabeth Howard
# Thomas Hughes
# Henry Hunt
# T Hunt
# J Hurnard
# John C Isaac
# John James
# Charles Janson
# Samuel Jesper
# Benjamin Jowett (2)
# John Jun Jowett
# Robert Jowett (2)
# John King
# Samuel King
# Thomas King
# Alfred Kitching
# C Knight
# John Lee
# x Leitch
# Thomas Letchmore
# Thomas x Jun Letchmore
# Thomas Letchworth
# Thomas Jun Letchworth
# Thomas x Jun Letchworth
# S Lloyd
# Edward Lucas
# Rebecca Lucas
# Thomas Marriage
# John Marsh
# R Marsh
# William Matthews
# William Mattravers
# D Miller
# John Morrison
# E Neave
# Mary Overend
# W J Palmer
# J Pears
# Edward Priestman (2)
# John Priestman
# James Ransome
# Robert Ransome
# William Rathbone
# J Jun Read
# Edward Richardson
# Henry Richardson
# W Richardson
# R M Rickman
# S Rickman
# J Rooke
# Alfred Rosling
# John S Rowntree
# Joseph Rowntree
# Samuel Rundall
# Henry Russell
# Joseph Sams
# J A Sanders
# Mary Sansom
# Micheal Scatterthwaite
# S Scatterthwaite
# Benjamin Seebohm
# William Seebohm
# Charles Sessions
# Robert Simpson
# Alfred Smith
# Edward Smith
# Richard Smith
# Ann Snowden
# C Southall
# William Southall
# William Sparkes
# Joseph F Spence
# L Squire
# Mary Steevens
# Henry Sterry
# Richard Sterry
# John Stevens
# Joseph Sturge (Mrs)
# Sarah Styles
# George N Tatham
# Mary Ann Tatham
# Edward Taylor
# F Taylor
# H Taylor
# A Thistlethwaite
# F J Thompson
# Josiah Thompson
# Thomas Thompson
# W Thompson
# George Treffry
# Frederick Tuckett
# W Tuke
# Thomas Turner
# James E Veale
# Jonathan Walker
# Ann Wallis
# John Warner
# Alfred Waterhouse
# Mary Waterhouse
# R Waterhouse
# Thomas Wedmore
# James Wells
# Daniel Wheeler
# W Whiting
# John Jun Williams
# W R Williams
# Charles Wilson
# George Wilson
# Isaac Wilson
# Joseph Wilson
# Rebecca Wilson
# H Wise
# William Woods
# Louisa Wright
# James Bowden
# William Nash
# Joseph Sturge
# William Jun Grimshaw
# Henry Knight
# Edward Paull
# Robert Jun Alsop
# Abram Rawlinson Barclay
# John Barclay
# Richard Barrett
# John Thomas Barry
# Peter Bedford
# John Bell
# Thomas Christy
# Samuel Darton
# Josiah Forster
# Robert Forster
# William Forster
# Joseph Talwin Foster
# John Hamilton
# Edwd Harris
# Geo Holmes
# Robert Howard
# John Kitching
# Joseph Neatby
# John Sanderson
# Joseph Shewell
# George Stacey
#  Joseph Storrs
# John M Albright
# G W Alexander
# Henry Alexander
# R D Alexander
# Thomas Allis
# John D Appleton
# Caroline Armistead
# Joseph Armistead
# Edward Ash
# Alfred Backhouse
# Edmund Backhouse
# Edward Jun Backhouse
# James Jun Backhouse
# John Church Backhouse
# J E Baker
# James Baker
# A P Balkwill
# William Ball
# Eliza Barclay
# J Gurney Barclay
# Jonathan Barrett
# R Barrett
# R C Barrow
# S Barter
# John D Bassett
# John Baynes
# John Beaumont
# Rebecca Beaumont
# William Beaumont
# Samuel Beck
# Deborah Beesley
# Paul Bevan
# Robert Bevan
# Martha A Binyon
# Thomas Binyon
# S Birchall
# Thomas Blain
# J Blunsom
# W Bott
# Christopher Bowley
# W C Bowley
# Edwin Bracher
# James Bracher
# Lucy Bradshaw
# G S Brady
# Joseph B Braithwaite
# S Braithwaite
# Charles Brewin
# Robert Brewin
# Thomas Brewin
# William Brewin
# Francis Brown
# Gopsill Brown
# W W Brown
# J F Burgess
# Wilson Burgess
# Henry Burlingham
# Jonathan Burtt
# P Burtt
# Edward North Buxton
# James Cadbury
# John M Candler
# Edward Carroll
# Joseph Cash
# Newman Cash
# William Cash
# R D Catchpool
# Thomas Catchpool
# Thomas Chalk
# Elizabeth Charelton
# James Charleton
# Robert Charleton
# Richard Christy
# Cyrus Clark
# James Clark (2)
# Joseph Clark
# W S Clark
# George Cook
# J H Cotterell
# Elliott Cresson
# W D Crewdson
# Ann Cropper
# James Cropper
# John Cropper
# Joseph Crosfield
# William Crosfield
# Jeremiah Cross
# Martha Cross
# Edward A Crouch
# Abraham Crowley
# Frederick Crowley
# J Cudworth
# Mary Cudworth
# William Cudworth
# Lucy Darby
# Richard Day
# William Dent
# Barnard Dickinson
# Elizabeth G Dimsdale
# J Doubleday
# R Doubleday
# Joseph Eaton
# Thomas Emmott
# Mary Exton
# William Exton
# Abraham Fisher
# Rachel Fowler
# Thomas Fowler
# Alfred L Fox
# Francis E Fox
# Frederick H Fox
# J G Fox
# R Barclay Fox
# Philip Frith
# Frederick Fryer
# John Gayner
# Deborah Gibson
# E Gilkes
# Charles Gillett
# Jonathan Gillett
# Burwood Godlee
# Alexander Grace
# Anna Gurney
# Edmund Gurney
# Henry E Gurney
# John Gurney
# Samuel Gurney
# Daniel P Hack
# John Barton Hack
# Cornelius Hanbury
# Cornelius x Jun Hanbury
# Daniel Bell Hanbury
# Samuel Hare
# Charles L Harford
# John Harford
# Summers Harford
# William Hargreaves
# John Harlock
# Theodore Harris
# Gray Hester
# M A Hewitson
# Henry Hipsley
# John Hodgkin
# J Holdsworth
# Richard Holdsworth
# G B Holmes
# S Horman-Fisher
# Robert Horne
# John Horniman
# Charles Horsnaill
# W C Horsnaill
# Sarah Hotham
# Luke Howard
# William Howitt
# Rachel Hubbert
# Joseph Hudson
# John Huntley
# Joseph Huntley
# Martha Hutchinson
# R Impey
# Edward James
# A Janson
# William Janson
# Andrew Johnston
# Andrew & Jun Johnston
# John Jowett
# W D King
# J H Knight
# T Knott
# Edward A Leatham
# Isabella Lister
# Wilson Lloyd
# Haggar Lowe
# Edmund Lucas
# Frederick Lucas
# Jeffrey Lucas
# Martha Lucas
# Samuel Lucas
# William Jun Lucas
# Harford Lury
# J E Lury
# W Mann
# Caroline Marriage
# Edward Marsh
# Thomas William Marsh
# Thomas Maw
# Edward C May
# Francis May
# John Mayfield
# Josiah Merrick
# John Morland
# George L Neighbour
# Josiah Newman
# William Norris
# Thomas Norton
# William Norton
# William Nutter
# J J Packer
# George Palmer
# Reuben C Payne
# Arthur Pease
# Edward Pease
# Gurney Pease
# Henry Fell Pease
# John Pease
# John B Pease
# Joseph Pease
# Joseph Whitwell Pease
# Susan Pease
# Thomas Pease
# Algernon Peckover
# William Peckover
# Robert H Penney
# Isaac Pitt
# Jacob Post
# Joseph T Price
# Lydia Prideaux
# Samuel Priestman
# John Pryor
# G R Pumphrey
# W P Read
# Isaac Reckitt
# Jonathan Rees
# Jane Reynolds
# G E Richardson
# John Rickman
# Josephina Rickman
# Matilda Rickman
# Priscilla Rickman
# R Rickman
# R P Rickman
# Isaac Robson
# J S Robson
# Joseph Rosling
# Samuel Rosling
# John Rowntree
# W Rowntree
# Sarah Rundell
# John F Rutter
# Samuel Rutter
# E Sayce
# Hannah Scarr
# F Seebohm
# John R Seekings
# James Sessions
# Lydia Sessions
# Robert Sessions
# Abraham Sewell
# E F Sewell
# Joseph Sewell
# Phillip Sewell
# Joseph Sharples
# John T Shewell
# Thomas Short
# W Dillwyn Sims
# W Skinner
# Bartholomew Smith
# George Smithson
# E P Southall
# Sarah Southall
# J M Sparkes
# H Squire
# John Stansfield
# Joseph Sterry
# Sarah Sterry
# J L Stevens
# Charles Sturge
# Edmund Sturge
# George Sturge
# H J Sturge
# Samuel Sturge
# Thomas M Sturge
# Walter Sturge
# Jemima Swan
# William Tanner
# W Tatum
# Edward Thomas
# George Thomas
# Samuel Thompson
# Fielden Thorpe
# E O Tindale
# Robert Tindall
# Joshua Treffry
# Nathaniel Tregellis
# Elizabeth Tuckett
# Francis Tuckett
# P Debell Tuckett
# D Tuke
# J H Tuke
# Samuel Tuke
# Ann Tweedy
# R Tweedy
# William Tweedy
# Richard Veale
# William Veale
# John Wadge
# F J Walker
# Marriage Wallis
# Charles B Warner
# Septimus Warner
# Lucy Westcombe
# Thomas Westcombe
# Benjamin Wheeler
# Frederick Wheeler
# Samuel Wheeler
# John Whiting
# John Wiblin
# Caleb Williams
# John E Wilson
# Joshua Wilson
# F Woodhead
# W Woolston
# Francis Wright
# S W Wright

# %%
nx.write_gexf(G, 'ceda_quakers.gexf')
